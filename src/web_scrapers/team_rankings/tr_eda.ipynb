# %%
import pandas as pd
import os
print(os.getcwd())
# Out:
# /Users/DanPfeiffer/Documents/code/data-collector/src/web_scrapers/team_rankings

# %%
raw_df = pd.read_excel("../../../output/team_rankings/full_stats.xlsx")

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20128 entries, 0 to 20127
# Columns: 1589 entries, rankings_predictive_rank to penalties_opponent_penalty_rate_last_yr
# dtypes: float64(1261), int64(314), object(14)
# memory usage: 244.0+ MB

# %%
for col in raw_df.columns:
    if any(sub in col for sub in ["this_yr", "last_yr"]):
        print(f"'{col}',")
# Out:
# 'offense_scoring_points_per_game_this_yr',
# 'offense_scoring_points_per_game_last_yr',
# 'offense_scoring_points_per_game_delta_this_yr',
# 'offense_scoring_points_per_game_delta_last_yr',
# 'offense_scoring_yards_per_point_this_yr',
# 'offense_scoring_yards_per_point_last_yr',
# 'offense_scoring_yards_per_point_delta_this_yr',
# 'offense_scoring_yards_per_point_delta_last_yr',
# 'offense_scoring_points_per_play_this_yr',
# 'offense_scoring_points_per_play_last_yr',
# 'offense_scoring_points_per_play_margin_this_yr',
# 'offense_scoring_points_per_play_margin_last_yr',
# 'offense_scoring_td_per_game_this_yr',
# 'offense_scoring_td_per_game_last_yr',
# 'offense_scoring_rz_attempts_this_yr',
# 'offense_scoring_rz_attempts_last_yr',
# 'offense_scoring_rz_tds_this_yr',
# 'offense_scoring_rz_tds_last_yr',
# 'offense_scoring_rz_td_pcnt_this_yr',
# 'offense_scoring_rz_td_pcnt_last_yr',
# 'offense_scoring_ep_att_this_yr',
# 'offense_scoring_ep_att_last_yr',
# ...

# %%
keep_cols = [
    'date',
'team',
'rankings_predictive_rating',
'rankings_home_rating',
'rankings_road_rank',
'rankings_home_advantage_rating',
'rankings_sos_rating',
'rankings_sos_basic_rating',
'rankings_luck_rating',
'rankings_consistency_rating',
'offense_scoring_points_per_game_this_yr',
'offense_scoring_points_per_game_last_yr',
'offense_scoring_points_per_game_delta_this_yr',
'offense_scoring_points_per_game_delta_last_yr',
'offense_scoring_yards_per_point_this_yr',
'offense_scoring_yards_per_point_last_yr',
'offense_scoring_yards_per_point_delta_this_yr',
'offense_scoring_yards_per_point_delta_last_yr',
'offense_scoring_points_per_play_this_yr',
'offense_scoring_points_per_play_last_yr',
'offense_scoring_td_per_game_this_yr',
'offense_scoring_td_per_game_last_yr',
'offense_scoring_rz_attempts_this_yr',
'offense_scoring_rz_attempts_last_yr',
'offense_scoring_rz_tds_this_yr',
'offense_scoring_rz_tds_last_yr',
'offense_scoring_rz_td_pcnt_this_yr',
'offense_scoring_rz_td_pcnt_last_yr',
'offense_scoring_points_per_fg_this_yr',
'offense_scoring_points_per_fg_last_yr',
'offense_scoring_ep_pcnt_this_yr',
'offense_scoring_ep_pcnt_last_yr',
'offense_scoring_2pt_pcnt_this_yr',
'offense_scoring_2pt_pcnt_last_yr',
'offense_scoring_off_td_this_yr',
'offense_scoring_off_td_last_yr',
'offense_scoring_def_td_this_yr',
'offense_scoring_def_td_last_yr',
'offense_scoring_spec_td_this_yr',
'offense_scoring_spec_td_last_yr',
'offense_scoring_off_ppg_this_yr',
'offense_scoring_off_ppg_last_yr',
'offense_scoring_def_ppg_this_yr',
'offense_scoring_def_ppg_last_yr',
'offense_scoring_spec_ppg_this_yr',
'offense_scoring_spec_ppg_last_yr',
'offense_scoring_point_share_pcnt_this_yr',
'offense_scoring_point_share_pcnt_last_yr',
'offense_total_yards_this_yr',
'offense_total_yards_last_yr',
'offense_total_plays_this_yr',
'offense_total_plays_last_yr',
'offense_total_yards_per_play_this_yr',
'offense_total_yards_per_play_last_yr',
'offense_total_1st_downs_this_yr',
'offense_total_1st_downs_last_yr',
'offense_total_3rd_down_conversions_this_yr',
'offense_total_3rd_down_conversions_last_yr',
'offense_total_4th_downs_this_yr',
'offense_total_4th_downs_last_yr',
'offense_total_4th_down_conversions_this_yr',
'offense_total_4th_down_conversions_last_yr',
'offense_total_time_of_possession_this_yr',
'offense_total_time_of_possession_last_yr',
'offense_total_seconds_per_play_this_yr',
'offense_total_seconds_per_play_last_yr',
'offense_total_1st_downs_per_play_this_yr',
'offense_total_1st_downs_per_play_last_yr',
'offense_total_3rd_down_conversion_pcnt_this_yr',
'offense_total_3rd_down_conversion_pcnt_last_yr',
'offense_total_4th_down_conversion_pcnt_this_yr',
'offense_total_4th_down_conversion_pcnt_last_yr',
'offense_total_punts_per_play_this_yr',
'offense_total_punts_per_play_last_yr',
'offense_total_punts_per_score_this_yr',
'offense_total_punts_per_score_last_yr',
'offense_total_opp_tackles_this_yr',
'offense_total_opp_tackles_last_yr',
'offense_total_opp_solo_tackles_this_yr',
'offense_total_opp_solo_tackles_last_yr',
'offense_total_opp_asst_tackles_this_yr',
'offense_total_opp_asst_tackles_last_yr',
'offense_rushing_attempts_this_yr',
'offense_rushing_attempts_last_yr',
'offense_rushing_yds_this_yr',
'offense_rushing_yds_last_yr',
'offense_rushing_1st_downs_this_yr',
'offense_rushing_1st_downs_last_yr',
'offense_rushing_tds_this_yr',
'offense_rushing_tds_last_yr',
'offense_rushing_ypa_this_yr',
'offense_rushing_ypa_last_yr',
'offense_rushing_play_pcnt_this_yr',
'offense_rushing_play_pcnt_last_yr',
'offense_rushing_td_pcnt_this_yr',
'offense_rushing_td_pcnt_last_yr',
'offense_rushing_1st_down_pcnt_this_yr',
'offense_rushing_1st_down_pcnt_last_yr',
'offense_rushing_yards_pcnt_this_yr',
'offense_rushing_yards_pcnt_last_yr',
'offense_passing_attempts_this_yr',
'offense_passing_attempts_last_yr',
'offense_passing_completions_this_yr',
'offense_passing_completions_last_yr',
'offense_passing_incompletions_this_yr',
'offense_passing_incompletions_last_yr',
'offense_passing_completion_pcnt_this_yr',
'offense_passing_completion_pcnt_last_yr',
'offense_passing_yards_this_yr',
'offense_passing_yards_last_yr',
'offense_passing_yards_gross_this_yr',
'offense_passing_yards_gross_last_yr',
'offense_passing_ypa_this_yr',
'offense_passing_ypa_last_yr',
'offense_passing_ypc_this_yr',
'offense_passing_ypc_last_yr',
'offense_passing_td_this_yr',
'offense_passing_td_last_yr',
'offense_passing_td_pcnt_this_yr',
'offense_passing_td_pcnt_last_yr',
'offense_passing_sacks_this_yr',
'offense_passing_sacks_last_yr',
'offense_passing_sack_pcnt_this_yr',
'offense_passing_sack_pcnt_last_yr',
'offense_passing_1st_downs_this_yr',
'offense_passing_1st_downs_last_yr',
'offense_passing_1st_down_pcnt_this_yr',
'offense_passing_1st_down_pcnt_last_yr',
'offense_passing_pass_rtg_this_yr',
'offense_passing_pass_rtg_last_yr',
'offense_passing_play_pcnt_this_yr',
'offense_passing_play_pcnt_last_yr',
'offense_passing_yds_pcnt_this_yr',
'offense_passing_yds_pcnt_last_yr',
'offense_special_teams_non_off_td_this_yr',
'offense_special_teams_non_off_td_last_yr',
'offense_special_teams_fg_att_this_yr',
'offense_special_teams_fg_att_last_yr',
'offense_special_teams_fg_made_this_yr',
'offense_special_teams_fg_made_last_yr',
'offense_special_teams_fg_blocked_this_yr',
'offense_special_teams_fg_blocked_last_yr',
'offense_special_teams_kicking_ppg_this_yr',
'offense_special_teams_kicking_ppg_last_yr',
'offense_special_teams_punts_this_yr',
'offense_special_teams_punts_last_yr',
'offense_special_teams_punts_blocked_this_yr',
'offense_special_teams_punts_blocked_last_yr',
'offense_special_teams_gross_punt_yards_this_yr',
'offense_special_teams_gross_punt_yards_last_yr',
'offense_special_teams_net_punt_yards_this_yr',
'offense_special_teams_net_punt_yards_last_yr',
'offense_special_teams_fg_made_pcnt_all_this_yr',
'offense_special_teams_fg_made_pcnt_all_last_yr',
'offense_special_teams_fg_block_pcnt_this_yr',
'offense_special_teams_fg_block_pcnt_last_yr',
'offense_special_teams_fg_made_pcnt_this_yr',
'offense_special_teams_fg_made_pcnt_last_yr',
'offense_special_teams_punt_block_pcnt_this_yr',
'offense_special_teams_punt_block_pcnt_last_yr',
'offense_special_teams_net_punt_ypa_all_this_yr',
'offense_special_teams_net_punt_ypa_all_last_yr',
'offense_special_teams_gross_punt_ypa_this_yr',
'offense_special_teams_gross_punt_ypa_last_yr',
'offense_special_teams_net_punt_ypa_this_yr',
'offense_special_teams_net_punt_ypa_last_yr',
'defense_scoring_ppg_this_yr',
'defense_scoring_ppg_last_yr',
'defense_scoring_yards_per_point_this_yr',
'defense_scoring_yards_per_point_last_yr',
'defense_scoring_points_per_play_this_yr',
'defense_scoring_points_per_play_last_yr',
'defense_scoring_tds_this_yr',
'defense_scoring_tds_last_yr',
'defense_scoring_rz_attempts_this_yr',
'defense_scoring_rz_attempts_last_yr',
'defense_scoring_rz_tds_this_yr',
'defense_scoring_rz_tds_last_yr',
'defense_scoring_rz_td_pcnt_this_yr',
'defense_scoring_rz_td_pcnt_last_yr',
'defense_scoring_ep_att_this_yr',
'defense_scoring_ep_att_last_yr',
'defense_scoring_ep_made_this_yr',
'defense_scoring_ep_made_last_yr',
'defense_scoring_2pt_att_this_yr',
'defense_scoring_2pt_att_last_yr',
'defense_scoring_2pt_made_this_yr',
'defense_scoring_2pt_made_last_yr',
'defense_scoring_points_per_fga_this_yr',
'defense_scoring_points_per_fga_last_yr',
'defense_scoring_ep_pcnt_this_yr',
'defense_scoring_ep_pcnt_last_yr',
'defense_scoring_2pt_pcnt_this_yr',
'defense_scoring_2pt_pcnt_last_yr',
'defense_scoring_off_td_this_yr',
'defense_scoring_off_td_last_yr',
'defense_scoring_def_td_this_yr',
'defense_scoring_def_td_last_yr',
'defense_scoring_spec_td_this_yr',
'defense_scoring_spec_td_last_yr',
'defense_scoring_off_ppg_this_yr',
'defense_scoring_off_ppg_last_yr',
'defense_scoring_def_ppg_this_yr',
'defense_scoring_def_ppg_last_yr',
'defense_scoring_spec_ppg_this_yr',
'defense_scoring_spec_ppg_last_yr',
'defense_scoring_point_share_pcnt_this_yr',
'defense_scoring_point_share_pcnt_last_yr',
'defense_total_yards_this_yr',
'defense_total_yards_last_yr',
'defense_total_plays_this_yr',
'defense_total_plays_last_yr',
'defense_total_yards_per_play_this_yr',
'defense_total_yards_per_play_last_yr',
'defense_total_1st_downs_this_yr',
'defense_total_1st_downs_last_yr',
'defense_total_3rd_downs_this_yr',
'defense_total_3rd_downs_last_yr',
'defense_total_3rd_down_conversions_this_yr',
'defense_total_3rd_down_conversions_last_yr',
'defense_total_4th_downs_this_yr',
'defense_total_4th_downs_last_yr',
'defense_total_4th_down_conversions_this_yr',
'defense_total_4th_down_conversions_last_yr',
'defense_total_time_of_possession_this_yr',
'defense_total_time_of_possession_last_yr',
'defense_total_seconds_per_play_this_yr',
'defense_total_seconds_per_play_last_yr',
'defense_total_1st_downs_per_play_this_yr',
'defense_total_1st_downs_per_play_last_yr',
'defense_total_3rd_down_conversion_pcnt_this_yr',
'defense_total_3rd_down_conversion_pcnt_last_yr',
'defense_total_4th_down_conversion_pcnt_this_yr',
'defense_total_4th_down_conversion_pcnt_last_yr',
'defense_total_punts_per_play_this_yr',
'defense_total_punts_per_play_last_yr',
'defense_total_punts_per_score_this_yr',
'defense_total_punts_per_score_last_yr',
'defense_total_tackles_this_yr',
'defense_total_tackles_last_yr',
'defense_total_solo_tackles_this_yr',
'defense_total_solo_tackles_last_yr',
'defense_total_assisted_tackles_this_yr',
'defense_total_assisted_tackles_last_yr',
'defense_rushing_attempts_this_yr',
'defense_rushing_attempts_last_yr',
'defense_rushing_ypg_this_yr',
'defense_rushing_ypg_last_yr',
'defense_rushing_1st_downs_this_yr',
'defense_rushing_1st_downs_last_yr',
'defense_rushing_tds_this_yr',
'defense_rushing_tds_last_yr',
'defense_rushing_ypa_this_yr',
'defense_rushing_ypa_last_yr',
'defense_rushing_play_pcnt_this_yr',
'defense_rushing_play_pcnt_last_yr',
'defense_rushing_td_pcnt_this_yr',
'defense_rushing_td_pcnt_last_yr',
'defense_rushing_1st_down_pcnt_this_yr',
'defense_rushing_1st_down_pcnt_last_yr',
'defense_rushing_yards_percent_this_yr',
'defense_rushing_yards_percent_last_yr',
'defense_passing_attempts_this_yr',
'defense_passing_attempts_last_yr',
'defense_passing_completions_this_yr',
'defense_passing_completions_last_yr',
'defense_passing_incompletions_this_yr',
'defense_passing_incompletions_last_yr',
'defense_passing_completion_pcnt_this_yr',
'defense_passing_completion_pcnt_last_yr',
'defense_passing_yards_this_yr',
'defense_passing_yards_last_yr',
'defense_passing_yards_gross_this_yr',
'defense_passing_yards_gross_last_yr',
'defense_passing_ypa_this_yr',
'defense_passing_ypa_last_yr',
'defense_passing_ypc_this_yr',
'defense_passing_ypc_last_yr',
'defense_passing_1st_downs_this_yr',
'defense_passing_1st_downs_last_yr',
'defense_passing_tds_this_yr',
'defense_passing_tds_last_yr',
'defense_passing_td_pcnt_this_yr',
'defense_passing_td_pcnt_last_yr',
'defense_passing_pass_rtg_this_yr',
'defense_passing_pass_rtg_last_yr',
'defense_passing_sack_pcnt_this_yr',
'defense_passing_sack_pcnt_last_yr',
'defense_passing_play_pcnt_this_yr',
'defense_passing_play_pcnt_last_yr',
'defense_passing_yards_pcnt_this_yr',
'defense_passing_yards_pcnt_last_yr',
'defense_passing_sacks_this_yr',
'defense_passing_sacks_last_yr',
'defense_passing_1st_down_pcnt_this_yr',
'defense_passing_1st_down_pcnt_last_yr',
'defense_special_teams_non_off_td_this_yr',
'defense_special_teams_non_off_td_last_yr',
'defense_special_teams_fg_att_this_yr',
'defense_special_teams_fg_att_last_yr',
'defense_special_teams_fg_made_this_yr',
'defense_special_teams_fg_made_last_yr',
'defense_special_teams_fg_blocked_this_yr',
'defense_special_teams_fg_blocked_last_yr',
'defense_special_teams_kicking_ppg_this_yr',
'defense_special_teams_kicking_ppg_last_yr',
'defense_special_teams_punts_this_yr',
'defense_special_teams_punts_last_yr',
'defense_special_teams_punts_blocked_this_yr',
'defense_special_teams_punts_blocked_last_yr',
'defense_special_teams_gross_punt_yards_this_yr',
'defense_special_teams_gross_punt_yards_last_yr',
'defense_special_teams_net_punt_yards_this_yr',
'defense_special_teams_net_punt_yards_last_yr',
'defense_special_teams_kickoffs_this_yr',
'defense_special_teams_kickoffs_last_yr',
'defense_special_teams_touchbacks_this_yr',
'defense_special_teams_touchbacks_last_yr',
'defense_special_teams_kickoff_touchback_pcnt_this_yr',
'defense_special_teams_kickoff_touchback_pcnt_last_yr',
'defense_special_teams_fg_made_pcnt_all_this_yr',
'defense_special_teams_fg_made_pcnt_all_last_yr',
'defense_special_teams_fg_block_pcnt_this_yr',
'defense_special_teams_fg_block_pcnt_last_yr',
'defense_special_teams_fg_made_pcnt_this_yr',
'defense_special_teams_fg_made_pcnt_last_yr',
'defense_special_teams_punt_block_pcnt_this_yr',
'defense_special_teams_punt_block_pcnt_last_yr',
'defense_special_teams_net_punt_ypa_all_this_yr',
'defense_special_teams_net_punt_ypa_all_last_yr',
'defense_special_teams_gross_punt_ypa_this_yr',
'defense_special_teams_gross_punt_ypa_last_yr',
'defense_special_teams_net_punt_ypa_this_yr',
'defense_special_teams_net_punt_ypa_last_yr',
'off_turnovers_int_this_yr',
'off_turnovers_int_last_yr',
'off_turnovers_int_game_pcnt_this_yr',
'off_turnovers_int_game_pcnt_last_yr',
'off_turnovers_fumbles_this_yr',
'off_turnovers_fumbles_last_yr',
'off_turnovers_fumbles_lost_this_yr',
'off_turnovers_fumbles_lost_last_yr',
'off_turnovers_fumbles_not_lost_this_yr',
'off_turnovers_fumbles_not_lost_last_yr',
'off_turnovers_safeties_this_yr',
'off_turnovers_safeties_last_yr',
'off_turnovers_turnovers_this_yr',
'off_turnovers_turnovers_last_yr',
'off_turnovers_turnover_margin_this_yr',
'off_turnovers_turnover_margin_last_yr',
'off_turnovers_int_pcnt_this_yr',
'off_turnovers_int_pcnt_last_yr',
'off_turnovers_fumble_rec_pcnt_this_yr',
'off_turnovers_fumble_rec_pcnt_last_yr',
'off_turnovers_giveaway_fumble_rec_pcnt_this_yr',
'off_turnovers_giveaway_fumble_rec_pcnt_last_yr',
'off_turnovers_takeaway_fumble_rec_pcnt_this_yr',
'off_turnovers_takeaway_fumble_rec_pcnt_last_yr',
'def_turnovers_int_this_yr',
'def_turnovers_int_last_yr',
'def_turnovers_int_game_pcnt_this_yr',
'def_turnovers_int_game_pcnt_last_yr',
'def_turnovers_fumbles_this_yr',
'def_turnovers_fumbles_last_yr',
'def_turnovers_fumbles_lost_this_yr',
'def_turnovers_fumbles_lost_last_yr',
'def_turnovers_fumbles_not_lost_this_yr',
'def_turnovers_fumbles_not_lost_last_yr',
'def_turnovers_safeties_this_yr',
'def_turnovers_safeties_last_yr',
'def_turnovers_takeaways_this_yr',
'def_turnovers_takeaways_last_yr',
'def_turnovers_fumble_rec_pcnt_this_yr',
'def_turnovers_fumble_rec_pcnt_last_yr',
'def_turnovers_int_pcnt_this_yr',
'def_turnovers_int_pcnt_last_yr',
'def_turnovers_opp_fumble_rec_pcnt_this_yr',
'def_turnovers_opp_fumble_rec_pcnt_last_yr',
'def_turnovers_opp_giveaway_fumble_rec_pcnt_this_yr',
'def_turnovers_opp_giveaway_fumble_rec_pcnt_last_yr',
'def_turnovers_opp_takeaway_fumble_rec_pcnt_this_yr',
'def_turnovers_opp_takeaway_fumble_rec_pcnt_last_yr',
'penalties_penalties_this_yr',
'penalties_penalties_last_yr',
'penalties_penalty_yards_this_yr',
'penalties_penalty_yards_last_yr',
'penalties_penalty_1st_downs_this_yr',
'penalties_penalty_1st_downs_last_yr',
'penalties_yards_per_penalty_this_yr',
'penalties_yards_per_penalty_last_yr',
'penalties_penalty_rate_this_yr',
'penalties_penalty_rate_last_yr',
'penalties_opponent_penalties_this_yr',
'penalties_opponent_penalties_last_yr',
'penalties_opponent_penalty_yards_this_yr',
'penalties_opponent_penalty_yards_last_yr',
'penalties_opponent_penalty_1st_downs_this_yr',
'penalties_opponent_penalty_1st_downs_last_yr',
'penalties_opponent_yards_per_penalty_this_yr',
'penalties_opponent_yards_per_penalty_last_yr',
'penalties_opponent_penalty_rate_this_yr',
'penalties_opponent_penalty_rate_last_yr',
]

# %%
df = raw_df.copy()

# %%
for col in df.columns:
    print(col)
    print(df[col].describe())
    print()
# Out:
# rankings_predictive_rank
# count    20128.000000
# mean        16.500000
# std          9.233322
# min          1.000000
# 25%          8.750000
# 50%         16.500000
# 75%         24.250000
# max         32.000000
# Name: rankings_predictive_rank, dtype: float64
#
# date
# count          20128
# unique           629
# top       2010-11-24
# freq              32
# Name: date, dtype: object
#
# team
# count         20128
# unique           32
# top       Green Bay
# freq            629
# Name: team, dtype: object
#
# rankings_predictive_rating
# count    19982.000000
# mean        -0.003158
# std          4.168884
# min        -17.200000
# 25%         -2.800000
# 50%          0.000000
# 75%          2.700000
# max         14.200000
# Name: rankings_predictive_rating, dtype: float64
#
# rankings_predictive_hi
# count    20128.000000
# mean         9.635880
# std          7.890165
# min          1.000000
# 25%          3.000000
# 50%          7.000000
# 75%         15.000000
# ...

# %%
keep_cols = [col for col in df.columns if col not in ["]]
